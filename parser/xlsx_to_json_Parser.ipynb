# %%
import os
import pandas as pd
import json

def read_excel_files(folder_path):
    data = {}
    
    for filename in os.listdir(folder_path):
        if filename.endswith(".xlsx") or filename.endswith(".xls"):
            year = extract_year_from_filename(filename)
            file_path = os.path.join(folder_path, filename)
            df = pd.read_excel(file_path)
            cleaned_df = clean_excel(df)
            data[year] = df_to_json(cleaned_df)
    
    return data

'''
def extract_year_from_filename(filename):
    if "SoSe" in filename:
        year = filename.split("SoSe")[1].split(".")[0].strip()
    elif "WiSe" in filename:
        year = filename.split("WiSe")[1].split(".")[0].strip()
    else:
        year = filename.split(".")[0].strip()
    return year
'''

def extract_year_from_filename(filename):
    if "Immatrikulierte Studierende" in filename:
        year = filename.split("Studierende")[1].split(".")[0].strip()
    else:
        year = filename.split(".")[0].strip()
    return year


def clean_excel(df):
    start_index = find_table_start(df)
    if start_index is not None:
        df.columns = df.iloc[start_index]  # Setze die erste Zeile als Spaltennamen
        return df.iloc[start_index + 1:]   # Ignoriere die Kopfzeile und gib den Rest zurück
    else:
        return df

def find_table_start(df):
    for index, row in df.iterrows():
        if "St-Ort" in row.values:
            return index
    return None

def df_to_json(df):
    json_data = []
    
    for _, row in df.iterrows():
        entry = {}
        for column, value in row.items():
            key = str(column)
            if isinstance(value, pd.Timestamp):
                entry[key] = value.strftime("%Y-%m-%d %H:%M:%S")
            else:
                entry[key] = value
        json_data.append(entry)
    
    return json_data

# Beispielaufruf
folder_path = "Studierendendaten_HSB-gesamt/"
data = read_excel_files(folder_path)
print(json.dumps(data, indent=4))


# Pfad zur Ausgabedatei festlegen
output_file_path = "Fakultätsdaten.json"

# JSON-Daten in Datei schreiben
with open(output_file_path, "w") as output_file:
    json.dump(data, output_file, indent=4)

print("Daten erfolgreich in", output_file_path, "gespeichert.")
# Out:
# {
#     "SoSe 2014": [
#         {
#             "St-Ort": "IG",
#             "FAK": "1 ",
#             "Stg-Nr": "713",
#             "Studiengang-Drucktext": "East Asian Management MBA",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "EAM MBA   ",
#             "HSB-Gesamt": 6,
#             "D-Gesamt": 4,
#             "M\u00e4nnlich-D": 3,
#             "Weiblich-D": 1,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "714",
#             "Studiengang-Drucktext": "DS Betriebswirtschaft BA ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "DSBW BA   ",
#             "HSB-Gesamt": 82,
#             "D-Gesamt": 81,
#             "M\u00e4nnlich-D": 36,
#             "Weiblich-D": 45,
#             "A-Gesamt": 1,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "719",
#             "Studiengang-Drucktext": "DS Public Admin BA       ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "DSPA BA   ",
#             "HSB-Gesamt": 84,
#             "D-Gesamt": 84,
#             "M\u00e4nnlich-D": 26,
#             "Weiblich-D": 58,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "888",
#             "Studiengang-Drucktext": "Int. Business Studies    ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "IBS POOL  ",
#             "HSB-Gesamt": 138,
#             "D-Gesamt": 2,
#             "M\u00e4nnlich-D": 1,
#             "Weiblich-D": 1,
#             "A-Gesamt": 136,
#             "M\u00e4nnlich-A": 57,
#             "Weiblich-A": 79,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 3,
#             "StdAnf-M": 1,
#             "StdAnf-W": 2,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "IG",
#             "FAK": "1 ",
#             "Stg-Nr": "929",
#             "Studiengang-Drucktext": "Global Management MBA    ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "MGM MBA   ",
#             "HSB-Gesamt": 27,
#             "D-Gesamt": 3,
#             "M\u00e4nnlich-D": 0,
#             "Weiblich-D": 3,
#             "A-Gesamt": 24,
#             "M\u00e4nnlich-A": 18,
#             "Weiblich-A": 6,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "IG",
#             "FAK": "1 ",
#             "Stg-Nr": "932",
#             "Studiengang-Drucktext": "European Studies MA      ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "MES MA    ",
#             "HSB-Gesamt": 26,
#             "D-Gesamt": 5,
#             "M\u00e4nnlich-D": 1,
#             "Weiblich-D": 4,
#             "A-Gesamt": 21,
#             "M\u00e4nnlich-A": 12,
#             "Weiblich-A": 9,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "IG",
#             "FAK": "1 ",
#             "Stg-Nr": "934",
#             "Studiengang-Drucktext": "Business Administration  ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "BA MBA    ",
#             "HSB-Gesamt": 55,
#             "D-Gesamt": 45,
#             "M\u00e4nnlich-D": 34,
#             "Weiblich-D": 11,
#             "A-Gesamt": 10,
#             "M\u00e4nnlich-A": 5,
#             "Weiblich-A": 5,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 9,
#             "StdAnf-M": 7,
#             "StdAnf-W": 2,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "937",
#             "Studiengang-Drucktext": "IS Volkswirtschaft BA    ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISVW BA   ",
#             "HSB-Gesamt": 119,
#             "D-Gesamt": 94,
#             "M\u00e4nnlich-D": 68,
#             "Weiblich-D": 26,
#             "A-Gesamt": 25,
#             "M\u00e4nnlich-A": 11,
#             "Weiblich-A": 14,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "IG",
#             "FAK": "1 ",
#             "Stg-Nr": "939",
#             "Studiengang-Drucktext": "Int. Tourism Managem. MBA",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "MTM MBA   ",
#             "HSB-Gesamt": 15,
#             "D-Gesamt": 3,
#             "M\u00e4nnlich-D": 0,
#             "Weiblich-D": 3,
#             "A-Gesamt": 12,
#             "M\u00e4nnlich-A": 8,
#             "Weiblich-A": 4,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "H\u00d6",
#             "FAK": "1 ",
#             "Stg-Nr": "940",
#             "Studiengang-Drucktext": "IS Steuer/Wirtschaftsrech",
#             "Abschluss": "Diplom",
#             "Stg-Kurztext": "ISWR      ",
#             "HSB-Gesamt": 28,
#             "D-Gesamt": 22,
#             "M\u00e4nnlich-D": 15,
#             "Weiblich-D": 7,
#             "A-Gesamt": 6,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 4,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "IG",
#             "FAK": "1 ",
#             "Stg-Nr": "957",
#             "Studiengang-Drucktext": "Int. Master Bus.Admin.MBA",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "IMBA MBA  ",
#             "HSB-Gesamt": 39,
#             "D-Gesamt": 6,
#             "M\u00e4nnlich-D": 6,
#             "Weiblich-D": 0,
#             "A-Gesamt": 33,
#             "M\u00e4nnlich-A": 18,
#             "Weiblich-A": 15,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 1,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "964",
#             "Studiengang-Drucktext": "ES Wirtschaft&Verwalt. BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ESWV BA   ",
#             "HSB-Gesamt": 213,
#             "D-Gesamt": 176,
#             "M\u00e4nnlich-D": 73,
#             "Weiblich-D": 103,
#             "A-Gesamt": 37,
#             "M\u00e4nnlich-A": 14,
#             "Weiblich-A": 23,
#             "BeurlaubteGesamt": 7,
#             "Beurlaubte-M": 3,
#             "Beurlaubte-W": 4,
#             "StdAnfGesamt": 2,
#             "StdAnf-M": 0,
#             "StdAnf-W": 2,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "965",
#             "Studiengang-Drucktext": "IS Global Management BA  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISGM BA   ",
#             "HSB-Gesamt": 191,
#             "D-Gesamt": 157,
#             "M\u00e4nnlich-D": 79,
#             "Weiblich-D": 78,
#             "A-Gesamt": 34,
#             "M\u00e4nnlich-A": 16,
#             "Weiblich-A": 18,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "966",
#             "Studiengang-Drucktext": "IS Wirtschaftsing. BEng  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISWI BEng ",
#             "HSB-Gesamt": 204,
#             "D-Gesamt": 182,
#             "M\u00e4nnlich-D": 158,
#             "Weiblich-D": 24,
#             "A-Gesamt": 22,
#             "M\u00e4nnlich-A": 18,
#             "Weiblich-A": 4,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "967",
#             "Studiengang-Drucktext": "IS Tourismusmanagement BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISTM BA   ",
#             "HSB-Gesamt": 202,
#             "D-Gesamt": 182,
#             "M\u00e4nnlich-D": 37,
#             "Weiblich-D": 145,
#             "A-Gesamt": 20,
#             "M\u00e4nnlich-A": 5,
#             "Weiblich-A": 15,
#             "BeurlaubteGesamt": 3,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 2,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 0,
#             "StdAnf-W": 1,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "IG",
#             "FAK": "1 ",
#             "Stg-Nr": "968",
#             "Studiengang-Drucktext": "Kulturmanagement MA      ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "MKM MA    ",
#             "HSB-Gesamt": 34,
#             "D-Gesamt": 22,
#             "M\u00e4nnlich-D": 3,
#             "Weiblich-D": 19,
#             "A-Gesamt": 12,
#             "M\u00e4nnlich-A": 6,
#             "Weiblich-A": 6,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 0,
#             "StdAnf-W": 1,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "974",
#             "Studiengang-Drucktext": "Betriebswirtschaft B.A.  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "BW    B.A.",
#             "HSB-Gesamt": 408,
#             "D-Gesamt": 349,
#             "M\u00e4nnlich-D": 217,
#             "Weiblich-D": 132,
#             "A-Gesamt": 59,
#             "M\u00e4nnlich-A": 28,
#             "Weiblich-A": 31,
#             "BeurlaubteGesamt": 7,
#             "Beurlaubte-M": 4,
#             "Beurlaubte-W": 3,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "975",
#             "Studiengang-Drucktext": "European Fin.& Accoun. BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "EFA BA    ",
#             "HSB-Gesamt": 138,
#             "D-Gesamt": 120,
#             "M\u00e4nnlich-D": 70,
#             "Weiblich-D": 50,
#             "A-Gesamt": 18,
#             "M\u00e4nnlich-A": 8,
#             "Weiblich-A": 10,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "976",
#             "Studiengang-Drucktext": "Managem. im Handel BA    ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "MiH BA    ",
#             "HSB-Gesamt": 164,
#             "D-Gesamt": 157,
#             "M\u00e4nnlich-D": 100,
#             "Weiblich-D": 57,
#             "A-Gesamt": 7,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 6,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 2,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "977",
#             "Studiengang-Drucktext": "Betriebsw./Intern.Man. BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "BIM BA    ",
#             "HSB-Gesamt": 270,
#             "D-Gesamt": 184,
#             "M\u00e4nnlich-D": 70,
#             "Weiblich-D": 114,
#             "A-Gesamt": 86,
#             "M\u00e4nnlich-A": 35,
#             "Weiblich-A": 51,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "978",
#             "Studiengang-Drucktext": "Angw. Wirt.Spr. BA / AR  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "AWS/AR BA ",
#             "HSB-Gesamt": 110,
#             "D-Gesamt": 85,
#             "M\u00e4nnlich-D": 34,
#             "Weiblich-D": 51,
#             "A-Gesamt": 25,
#             "M\u00e4nnlich-A": 13,
#             "Weiblich-A": 12,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "979",
#             "Studiengang-Drucktext": "Angw. Wirt.Spr. BA / JA  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "AWS/JA BA ",
#             "HSB-Gesamt": 100,
#             "D-Gesamt": 94,
#             "M\u00e4nnlich-D": 45,
#             "Weiblich-D": 49,
#             "A-Gesamt": 6,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 5,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "980",
#             "Studiengang-Drucktext": "Angw. Wirt.Spr. BA / CH  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "AWS/CH BA ",
#             "HSB-Gesamt": 142,
#             "D-Gesamt": 123,
#             "M\u00e4nnlich-D": 47,
#             "Weiblich-D": 76,
#             "A-Gesamt": 19,
#             "M\u00e4nnlich-A": 5,
#             "Weiblich-A": 14,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "984",
#             "Studiengang-Drucktext": "IS Econ.&Busin Admin. MA ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "ISEB MA   ",
#             "HSB-Gesamt": 26,
#             "D-Gesamt": 24,
#             "M\u00e4nnlich-D": 12,
#             "Weiblich-D": 12,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 2,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "1 ",
#             "Stg-Nr": "985",
#             "Studiengang-Drucktext": "Business Management MA   ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "BM MA     ",
#             "HSB-Gesamt": 63,
#             "D-Gesamt": 54,
#             "M\u00e4nnlich-D": 24,
#             "Weiblich-D": 30,
#             "A-Gesamt": 9,
#             "M\u00e4nnlich-A": 3,
#             "Weiblich-A": 6,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 2,
#             "StdAnfGesamt": 22,
#             "StdAnf-M": 8,
#             "StdAnf-W": 14,
#             "FAKsort": "1"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "2A",
#             "Stg-Nr": "721",
#             "Studiengang-Drucktext": "Architektur/Env.Design MA",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "A-b MA    ",
#             "HSB-Gesamt": 10,
#             "D-Gesamt": 7,
#             "M\u00e4nnlich-D": 4,
#             "Weiblich-D": 3,
#             "A-Gesamt": 3,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "2"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "2A",
#             "Stg-Nr": "949",
#             "Studiengang-Drucktext": "Architektur/Env.Design MA",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "A MA      ",
#             "HSB-Gesamt": 81,
#             "D-Gesamt": 77,
#             "M\u00e4nnlich-D": 39,
#             "Weiblich-D": 38,
#             "A-Gesamt": 4,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 2,
#             "BeurlaubteGesamt": 5,
#             "Beurlaubte-M": 2,
#             "Beurlaubte-W": 3,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 1,
#             "StdAnf-W": 0,
#             "FAKsort": "2"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "2A",
#             "Stg-Nr": "950",
#             "Studiengang-Drucktext": "Architektur BA           ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "A BA      ",
#             "HSB-Gesamt": 253,
#             "D-Gesamt": 212,
#             "M\u00e4nnlich-D": 102,
#             "Weiblich-D": 110,
#             "A-Gesamt": 41,
#             "M\u00e4nnlich-A": 19,
#             "Weiblich-A": 22,
#             "BeurlaubteGesamt": 5,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 5,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 0,
#             "StdAnf-W": 1,
#             "FAKsort": "2"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "2B",
#             "Stg-Nr": "951",
#             "Studiengang-Drucktext": "Bauingenieurwesen BSc    ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "BAU BSc   ",
#             "HSB-Gesamt": 402,
#             "D-Gesamt": 359,
#             "M\u00e4nnlich-D": 283,
#             "Weiblich-D": 76,
#             "A-Gesamt": 43,
#             "M\u00e4nnlich-A": 36,
#             "Weiblich-A": 7,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "2"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "2B",
#             "Stg-Nr": "952",
#             "Studiengang-Drucktext": "Bauingenieurwesen MSc    ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "BAU MSc   ",
#             "HSB-Gesamt": 50,
#             "D-Gesamt": 48,
#             "M\u00e4nnlich-D": 27,
#             "Weiblich-D": 21,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 7,
#             "StdAnf-M": 4,
#             "StdAnf-W": 3,
#             "FAKsort": "2"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "2U",
#             "Stg-Nr": "953",
#             "Studiengang-Drucktext": "IS Umwelttechnik BSc     ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISU BSc   ",
#             "HSB-Gesamt": 134,
#             "D-Gesamt": 115,
#             "M\u00e4nnlich-D": 84,
#             "Weiblich-D": 31,
#             "A-Gesamt": 19,
#             "M\u00e4nnlich-A": 10,
#             "Weiblich-A": 9,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "2"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "2U",
#             "Stg-Nr": "954",
#             "Studiengang-Drucktext": "Umwelttechnik MSc        ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "ISU MSc   ",
#             "HSB-Gesamt": 26,
#             "D-Gesamt": 20,
#             "M\u00e4nnlich-D": 9,
#             "Weiblich-D": 11,
#             "A-Gesamt": 6,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 4,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 4,
#             "StdAnf-M": 1,
#             "StdAnf-W": 3,
#             "FAKsort": "2"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "704",
#             "Studiengang-Drucktext": "IS Leisure and Tourism MA",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "MLT MA    ",
#             "HSB-Gesamt": 46,
#             "D-Gesamt": 38,
#             "M\u00e4nnlich-D": 7,
#             "Weiblich-D": 31,
#             "A-Gesamt": 8,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 6,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 14,
#             "StdAnf-M": 3,
#             "StdAnf-W": 11,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "722",
#             "Studiengang-Drucktext": "IS Journalistik BA       ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISJ BA    ",
#             "HSB-Gesamt": 130,
#             "D-Gesamt": 112,
#             "M\u00e4nnlich-D": 39,
#             "Weiblich-D": 73,
#             "A-Gesamt": 18,
#             "M\u00e4nnlich-A": 5,
#             "Weiblich-A": 13,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "726",
#             "Studiengang-Drucktext": "Politik&Nachhaltigkeit MA",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "PoNa MA   ",
#             "HSB-Gesamt": 10,
#             "D-Gesamt": 9,
#             "M\u00e4nnlich-D": 4,
#             "Weiblich-D": 5,
#             "A-Gesamt": 1,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 10,
#             "StdAnf-M": 5,
#             "StdAnf-W": 5,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "946",
#             "Studiengang-Drucktext": "IS Politikmanagement BA  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISPM BA   ",
#             "HSB-Gesamt": 162,
#             "D-Gesamt": 139,
#             "M\u00e4nnlich-D": 82,
#             "Weiblich-D": 57,
#             "A-Gesamt": 23,
#             "M\u00e4nnlich-A": 13,
#             "Weiblich-A": 10,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "955",
#             "Studiengang-Drucktext": "Soziale Arbeit BA        ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "SOZARB BA ",
#             "HSB-Gesamt": 389,
#             "D-Gesamt": 348,
#             "M\u00e4nnlich-D": 104,
#             "Weiblich-D": 244,
#             "A-Gesamt": 41,
#             "M\u00e4nnlich-A": 13,
#             "Weiblich-A": 28,
#             "BeurlaubteGesamt": 7,
#             "Beurlaubte-M": 2,
#             "Beurlaubte-W": 5,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 0,
#             "StdAnf-W": 1,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "959",
#             "Studiengang-Drucktext": "IS Pflege/Gesundh.Man. BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISPG BA   ",
#             "HSB-Gesamt": 115,
#             "D-Gesamt": 111,
#             "M\u00e4nnlich-D": 22,
#             "Weiblich-D": 89,
#             "A-Gesamt": 4,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 3,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 2,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "960",
#             "Studiengang-Drucktext": "IS Fachjournalistik BA   ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISFJ BA   ",
#             "HSB-Gesamt": 55,
#             "D-Gesamt": 55,
#             "M\u00e4nnlich-D": 19,
#             "Weiblich-D": 36,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 2,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "972",
#             "Studiengang-Drucktext": "IS Ang.Freizeitwissen. BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISAF BA   ",
#             "HSB-Gesamt": 206,
#             "D-Gesamt": 176,
#             "M\u00e4nnlich-D": 41,
#             "Weiblich-D": 135,
#             "A-Gesamt": 30,
#             "M\u00e4nnlich-A": 4,
#             "Weiblich-A": 26,
#             "BeurlaubteGesamt": 3,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 3,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "973",
#             "Studiengang-Drucktext": "Wissenschaftskommmun. MA ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "SC MA     ",
#             "HSB-Gesamt": 1,
#             "D-Gesamt": 1,
#             "M\u00e4nnlich-D": 0,
#             "Weiblich-D": 1,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "3 ",
#             "Stg-Nr": "981",
#             "Studiengang-Drucktext": "EuropeanWorld Polit. MA  ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "EWP MA    ",
#             "HSB-Gesamt": 17,
#             "D-Gesamt": 16,
#             "M\u00e4nnlich-D": 7,
#             "Weiblich-D": 9,
#             "A-Gesamt": 1,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 2,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "3"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "702",
#             "Studiengang-Drucktext": "DS Mechatronik BEng      ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "DMEI BEng ",
#             "HSB-Gesamt": 19,
#             "D-Gesamt": 19,
#             "M\u00e4nnlich-D": 17,
#             "Weiblich-D": 2,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "705",
#             "Studiengang-Drucktext": "DS Informatik BSc        ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "DSINF BSc ",
#             "HSB-Gesamt": 38,
#             "D-Gesamt": 38,
#             "M\u00e4nnlich-D": 32,
#             "Weiblich-D": 6,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "706",
#             "Studiengang-Drucktext": "ElekInfoTechSysteme BSc  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "BITS BSc  ",
#             "HSB-Gesamt": 11,
#             "D-Gesamt": 6,
#             "M\u00e4nnlich-D": 6,
#             "Weiblich-D": 0,
#             "A-Gesamt": 5,
#             "M\u00e4nnlich-A": 4,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "4 ",
#             "Stg-Nr": "707",
#             "Studiengang-Drucktext": "Zukunftsf\u00e4hige EneSysMEng",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "ZES MEng  ",
#             "HSB-Gesamt": 47,
#             "D-Gesamt": 45,
#             "M\u00e4nnlich-D": 38,
#             "Weiblich-D": 7,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 16,
#             "StdAnf-M": 14,
#             "StdAnf-W": 2,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "4 ",
#             "Stg-Nr": "716",
#             "Studiengang-Drucktext": "IS Techn/Angew Physik BSc",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISTAP BSc ",
#             "HSB-Gesamt": 53,
#             "D-Gesamt": 45,
#             "M\u00e4nnlich-D": 39,
#             "Weiblich-D": 6,
#             "A-Gesamt": 8,
#             "M\u00e4nnlich-A": 5,
#             "Weiblich-A": 3,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 1,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "717",
#             "Studiengang-Drucktext": "Informatik KSS M.Sc.     ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "KSS MSc   ",
#             "HSB-Gesamt": 32,
#             "D-Gesamt": 29,
#             "M\u00e4nnlich-D": 22,
#             "Weiblich-D": 7,
#             "A-Gesamt": 3,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 3,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 2,
#             "StdAnfGesamt": 12,
#             "StdAnf-M": 10,
#             "StdAnf-W": 2,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "4 ",
#             "Stg-Nr": "718",
#             "Studiengang-Drucktext": "DS Elektrotechnik BEng   ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "DET BEng  ",
#             "HSB-Gesamt": 8,
#             "D-Gesamt": 8,
#             "M\u00e4nnlich-D": 7,
#             "Weiblich-D": 1,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "725",
#             "Studiengang-Drucktext": "Mechatronik Beng         ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "MEI BEng  ",
#             "HSB-Gesamt": 8,
#             "D-Gesamt": 8,
#             "M\u00e4nnlich-D": 8,
#             "Weiblich-D": 0,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "936",
#             "Studiengang-Drucktext": "IS Digitale Medien BSc   ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "DM BSc    ",
#             "HSB-Gesamt": 27,
#             "D-Gesamt": 25,
#             "M\u00e4nnlich-D": 17,
#             "Weiblich-D": 8,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "4 ",
#             "Stg-Nr": "938",
#             "Studiengang-Drucktext": "Electronics Engineer. MSc",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "MScEE     ",
#             "HSB-Gesamt": 141,
#             "D-Gesamt": 23,
#             "M\u00e4nnlich-D": 22,
#             "Weiblich-D": 1,
#             "A-Gesamt": 118,
#             "M\u00e4nnlich-A": 93,
#             "Weiblich-A": 25,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 29,
#             "StdAnf-M": 22,
#             "StdAnf-W": 7,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "4 ",
#             "Stg-Nr": "945",
#             "Studiengang-Drucktext": "IS Imaging Physics BSc   ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISIP BSc  ",
#             "HSB-Gesamt": 5,
#             "D-Gesamt": 5,
#             "M\u00e4nnlich-D": 4,
#             "Weiblich-D": 1,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "982",
#             "Studiengang-Drucktext": "IS Digitale Medien MSc   ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "DM MSc    ",
#             "HSB-Gesamt": 1,
#             "D-Gesamt": 0,
#             "M\u00e4nnlich-D": 0,
#             "Weiblich-D": 0,
#             "A-Gesamt": 1,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "4 ",
#             "Stg-Nr": "986",
#             "Studiengang-Drucktext": "Elektrotechnik BEng      ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ET BEng   ",
#             "HSB-Gesamt": 296,
#             "D-Gesamt": 251,
#             "M\u00e4nnlich-D": 240,
#             "Weiblich-D": 11,
#             "A-Gesamt": 45,
#             "M\u00e4nnlich-A": 33,
#             "Weiblich-A": 12,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "987",
#             "Studiengang-Drucktext": "Technische Informat BSc  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "TI BSc    ",
#             "HSB-Gesamt": 171,
#             "D-Gesamt": 147,
#             "M\u00e4nnlich-D": 136,
#             "Weiblich-D": 11,
#             "A-Gesamt": 24,
#             "M\u00e4nnlich-A": 17,
#             "Weiblich-A": 7,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "988",
#             "Studiengang-Drucktext": "IS Techn. Informatik BSc ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISTI BSc  ",
#             "HSB-Gesamt": 45,
#             "D-Gesamt": 37,
#             "M\u00e4nnlich-D": 32,
#             "Weiblich-D": 5,
#             "A-Gesamt": 8,
#             "M\u00e4nnlich-A": 8,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 2,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "4 ",
#             "Stg-Nr": "989",
#             "Studiengang-Drucktext": "IS Mikro/Optosystemt. BSc",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISMO BSc  ",
#             "HSB-Gesamt": 7,
#             "D-Gesamt": 5,
#             "M\u00e4nnlich-D": 4,
#             "Weiblich-D": 1,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "990",
#             "Studiengang-Drucktext": "Int.Frauen-Stg. Inf. BSc ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "IFI BSc   ",
#             "HSB-Gesamt": 106,
#             "D-Gesamt": 75,
#             "M\u00e4nnlich-D": 0,
#             "Weiblich-D": 75,
#             "A-Gesamt": 31,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 31,
#             "BeurlaubteGesamt": 4,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 4,
#             "StdAnfGesamt": 2,
#             "StdAnf-M": 0,
#             "StdAnf-W": 2,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "4 ",
#             "Stg-Nr": "998",
#             "Studiengang-Drucktext": "IS Medieninformatik BSc  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "MI BSc    ",
#             "HSB-Gesamt": 227,
#             "D-Gesamt": 208,
#             "M\u00e4nnlich-D": 177,
#             "Weiblich-D": 31,
#             "A-Gesamt": 19,
#             "M\u00e4nnlich-A": 16,
#             "Weiblich-A": 3,
#             "BeurlaubteGesamt": 3,
#             "Beurlaubte-M": 3,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "4"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "708",
#             "Studiengang-Drucktext": "Energietechnik BEng      ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ENTEC BEng",
#             "HSB-Gesamt": 160,
#             "D-Gesamt": 136,
#             "M\u00e4nnlich-D": 129,
#             "Weiblich-D": 7,
#             "A-Gesamt": 24,
#             "M\u00e4nnlich-A": 22,
#             "Weiblich-A": 2,
#             "BeurlaubteGesamt": 3,
#             "Beurlaubte-M": 3,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "710",
#             "Studiengang-Drucktext": "DS Mech.Prod&Eng BEng    ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "MPE BEng  ",
#             "HSB-Gesamt": 57,
#             "D-Gesamt": 57,
#             "M\u00e4nnlich-D": 42,
#             "Weiblich-D": 15,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "711",
#             "Studiengang-Drucktext": "IS Ind.Mgmt&EngChina BEng",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "IMEC BEng ",
#             "HSB-Gesamt": 35,
#             "D-Gesamt": 33,
#             "M\u00e4nnlich-D": 25,
#             "Weiblich-D": 8,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 1,
#             "Beurlaubte-M": 1,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 1,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "712",
#             "Studiengang-Drucktext": "LuftfahrtsysT/Wart. BEng ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ILSTM BEng",
#             "HSB-Gesamt": 20,
#             "D-Gesamt": 20,
#             "M\u00e4nnlich-D": 18,
#             "Weiblich-D": 2,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "715",
#             "Studiengang-Drucktext": "Luft- u. Raumfahrt BEng  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "LUR BEng  ",
#             "HSB-Gesamt": 137,
#             "D-Gesamt": 120,
#             "M\u00e4nnlich-D": 107,
#             "Weiblich-D": 13,
#             "A-Gesamt": 17,
#             "M\u00e4nnlich-A": 16,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 2,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "5M",
#             "Stg-Nr": "723",
#             "Studiengang-Drucktext": "Aerospace Techn. MSc     ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "AT MSc    ",
#             "HSB-Gesamt": 23,
#             "D-Gesamt": 21,
#             "M\u00e4nnlich-D": 21,
#             "Weiblich-D": 0,
#             "A-Gesamt": 2,
#             "M\u00e4nnlich-A": 2,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 4,
#             "StdAnf-M": 4,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "ZI",
#             "FAK": "5M",
#             "Stg-Nr": "948",
#             "Studiengang-Drucktext": "Aeronaut.Managm. MEng    ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "MEAM MEng ",
#             "HSB-Gesamt": 24,
#             "D-Gesamt": 15,
#             "M\u00e4nnlich-D": 14,
#             "Weiblich-D": 1,
#             "A-Gesamt": 9,
#             "M\u00e4nnlich-A": 8,
#             "Weiblich-A": 1,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 1,
#             "StdAnf-M": 1,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "961",
#             "Studiengang-Drucktext": "Maschinenbau BEng        ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "M BEng    ",
#             "HSB-Gesamt": 251,
#             "D-Gesamt": 224,
#             "M\u00e4nnlich-D": 214,
#             "Weiblich-D": 10,
#             "A-Gesamt": 27,
#             "M\u00e4nnlich-A": 24,
#             "Weiblich-A": 3,
#             "BeurlaubteGesamt": 4,
#             "Beurlaubte-M": 3,
#             "Beurlaubte-W": 1,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "962",
#             "Studiengang-Drucktext": "Global Industr.Man. BEng ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "GIM BEng  ",
#             "HSB-Gesamt": 1,
#             "D-Gesamt": 1,
#             "M\u00e4nnlich-D": 1,
#             "Weiblich-D": 0,
#             "A-Gesamt": 0,
#             "M\u00e4nnlich-A": 0,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "963",
#             "Studiengang-Drucktext": "IS Luftfahrtsystemt. BEng",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ILST BEng ",
#             "HSB-Gesamt": 221,
#             "D-Gesamt": 214,
#             "M\u00e4nnlich-D": 204,
#             "Weiblich-D": 10,
#             "A-Gesamt": 7,
#             "M\u00e4nnlich-A": 5,
#             "Weiblich-A": 2,
#             "BeurlaubteGesamt": 2,
#             "Beurlaubte-M": 2,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 0,
#             "StdAnf-M": 0,
#             "StdAnf-W": 0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5M",
#             "Stg-Nr": "983",
#             "Studiengang-Drucktext": "Maschinenbau MEng        ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "M MEng    ",
#             "HSB-Gesamt": 23,
#             "D-Gesamt": 22,
#             "M\u00e4nnlich-D": 15,
#             "Weiblich-D": 7,
#             "A-Gesamt": 1,
#             "M\u00e4nnlich-A": 1,
#             "Weiblich-A": 0,
#             "BeurlaubteGesamt": 0,
#             "Beurlaubte-M": 0,
#             "Beurlaubte-W": 0,
#             "StdAnfGesamt": 8,
#             "StdAnf-M": 5,
#             "StdAnf-W": 3,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "5S",
#             "Stg-Nr": "701",
#             "Studiengang-Drucktext": "IS Shipping&Chartering BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISSC BA   ",
#             "HSB-Gesamt": 143,
#             "D-Gesamt": 125,
#             "M\u00e4nnlich-D": 73,
#             "Weiblich-D": 52,
# ...
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 6.0,
#             "StdAnf-M": 4.0,
#             "StdAnf-W": 2.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "5S",
#             "Stg-Nr": 701.0,
#             "Studiengang-Drucktext": "IS Shipping&Chartering BA",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISSC BA   ",
#             "HSB-Gesamt": 157.0,
#             "D-Gesamt": 42.0,
#             "M\u00e4nnlich-D": 28.0,
#             "Weiblich-D": 14.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 115.0,
#             "M\u00e4nnlich-A": 71.0,
#             "Weiblich-A": 44.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 5.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 5.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 33.0,
#             "StdAnf-M": 15.0,
#             "StdAnf-W": 18.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 709.0,
#             "Studiengang-Drucktext": "Schiffbau & Meerest. MEng",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "SuM MEng  ",
#             "HSB-Gesamt": 32.0,
#             "D-Gesamt": 16.0,
#             "M\u00e4nnlich-D": 10.0,
#             "Weiblich-D": 6.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 16.0,
#             "M\u00e4nnlich-A": 15.0,
#             "Weiblich-A": 1.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 8.0,
#             "StdAnf-M": 7.0,
#             "StdAnf-W": 1.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "5S",
#             "Stg-Nr": 720.0,
#             "Studiengang-Drucktext": "IS Ship Management B.Sc. ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISSM BSc  ",
#             "HSB-Gesamt": 38.0,
#             "D-Gesamt": 14.0,
#             "M\u00e4nnlich-D": 13.0,
#             "Weiblich-D": 1.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 24.0,
#             "M\u00e4nnlich-A": 22.0,
#             "Weiblich-A": 2.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 0.0,
#             "StdAnf-M": 0.0,
#             "StdAnf-W": 0.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 724.0,
#             "Studiengang-Drucktext": "Bionik: Mobile Sys. MSc  ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "BMS MSc   ",
#             "HSB-Gesamt": 22.0,
#             "D-Gesamt": 20.0,
#             "M\u00e4nnlich-D": 10.0,
#             "Weiblich-D": 10.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 2.0,
#             "M\u00e4nnlich-A": 0.0,
#             "Weiblich-A": 2.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 1.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 1.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 6.0,
#             "StdAnf-M": 3.0,
#             "StdAnf-W": 3.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "WS",
#             "FAK": "5S",
#             "Stg-Nr": 745.0,
#             "Studiengang-Drucktext": "IS Ship Man-Naut. B.Sc.  ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISMN BSc  ",
#             "HSB-Gesamt": 87.0,
#             "D-Gesamt": 46.0,
#             "M\u00e4nnlich-D": 33.0,
#             "Weiblich-D": 13.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 41.0,
#             "M\u00e4nnlich-A": 39.0,
#             "Weiblich-A": 2.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 26.0,
#             "StdAnf-M": 21.0,
#             "StdAnf-W": 5.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 769.0,
#             "Studiengang-Drucktext": "Schiffbau & Meerest. BEng",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "SuM BEng  ",
#             "HSB-Gesamt": 59.0,
#             "D-Gesamt": 50.0,
#             "M\u00e4nnlich-D": 41.0,
#             "Weiblich-D": 9.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 9.0,
#             "M\u00e4nnlich-A": 8.0,
#             "Weiblich-A": 1.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 1.0,
#             "Beurlaubte-M": 1.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 14.0,
#             "StdAnf-M": 12.0,
#             "StdAnf-W": 2.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 941.0,
#             "Studiengang-Drucktext": "Studium im Praxisverb.S&M",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "SuMPV BEng",
#             "HSB-Gesamt": 41.0,
#             "D-Gesamt": 39.0,
#             "M\u00e4nnlich-D": 31.0,
#             "Weiblich-D": 8.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 2.0,
#             "M\u00e4nnlich-A": 1.0,
#             "Weiblich-A": 1.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 5.0,
#             "StdAnf-M": 4.0,
#             "StdAnf-W": 1.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 943.0,
#             "Studiengang-Drucktext": "IS Techn/Angew. Bio. BSc ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISTAB BSc ",
#             "HSB-Gesamt": 163.0,
#             "D-Gesamt": 148.0,
#             "M\u00e4nnlich-D": 63.0,
#             "Weiblich-D": 84.0,
#             "nichtMW-D": 1.0,
#             "A-Gesamt": 15.0,
#             "M\u00e4nnlich-A": 2.0,
#             "Weiblich-A": 13.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 1.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 1.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 39.0,
#             "StdAnf-M": 10.0,
#             "StdAnf-W": 28.0,
#             "StdAnf-nichtMW": 1.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 944.0,
#             "Studiengang-Drucktext": "IS Bionik BSc            ",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "ISB BSc   ",
#             "HSB-Gesamt": 125.0,
#             "D-Gesamt": 119.0,
#             "M\u00e4nnlich-D": 62.0,
#             "Weiblich-D": 55.0,
#             "nichtMW-D": 2.0,
#             "A-Gesamt": 6.0,
#             "M\u00e4nnlich-A": 5.0,
#             "Weiblich-A": 1.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 34.0,
#             "StdAnf-M": 16.0,
#             "StdAnf-W": 18.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 947.0,
#             "Studiengang-Drucktext": "Techn/Angew. Bio. MSc    ",
#             "Abschluss": "Master",
#             "Stg-Kurztext": "ISTAB MSc ",
#             "HSB-Gesamt": 39.0,
#             "D-Gesamt": 35.0,
#             "M\u00e4nnlich-D": 21.0,
#             "Weiblich-D": 14.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 4.0,
#             "M\u00e4nnlich-A": 3.0,
#             "Weiblich-A": 1.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 2.0,
#             "StdAnf-M": 0.0,
#             "StdAnf-W": 2.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 969.0,
#             "Studiengang-Drucktext": "Schiffbau & Meerest. BEng",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "SuM BEng  ",
#             "HSB-Gesamt": 9.0,
#             "D-Gesamt": 9.0,
#             "M\u00e4nnlich-D": 8.0,
#             "Weiblich-D": 1.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 0.0,
#             "M\u00e4nnlich-A": 0.0,
#             "Weiblich-A": 0.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 0.0,
#             "StdAnf-M": 0.0,
#             "StdAnf-W": 0.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "5S",
#             "Stg-Nr": 970.0,
#             "Studiengang-Drucktext": "IS Schiffbau & Meer. BEng",
#             "Abschluss": "Bachelor",
#             "Stg-Kurztext": "IDINO BEng",
#             "HSB-Gesamt": 4.0,
#             "D-Gesamt": 0.0,
#             "M\u00e4nnlich-D": 0.0,
#             "Weiblich-D": 0.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 4.0,
#             "M\u00e4nnlich-A": 4.0,
#             "Weiblich-A": 0.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 0.0,
#             "StdAnf-M": 0.0,
#             "StdAnf-W": 0.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "5"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "HS",
#             "Stg-Nr": 801.0,
#             "Studiengang-Drucktext": "prime ING                ",
#             "Abschluss": NaN,
#             "Stg-Kurztext": "prime ING ",
#             "HSB-Gesamt": 6.0,
#             "D-Gesamt": 0.0,
#             "M\u00e4nnlich-D": 0.0,
#             "Weiblich-D": 0.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 6.0,
#             "M\u00e4nnlich-A": 6.0,
#             "Weiblich-A": 0.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 4.0,
#             "StdAnf-M": 4.0,
#             "StdAnf-W": 0.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "H"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "HS",
#             "Stg-Nr": 802.0,
#             "Studiengang-Drucktext": "prime MIN                ",
#             "Abschluss": NaN,
#             "Stg-Kurztext": "prime MIN ",
#             "HSB-Gesamt": 38.0,
#             "D-Gesamt": 0.0,
#             "M\u00e4nnlich-D": 0.0,
#             "Weiblich-D": 0.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 38.0,
#             "M\u00e4nnlich-A": 29.0,
#             "Weiblich-A": 9.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 25.0,
#             "StdAnf-M": 19.0,
#             "StdAnf-W": 6.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "H"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "HS",
#             "Stg-Nr": 803.0,
#             "Studiengang-Drucktext": "prime GKG                ",
#             "Abschluss": NaN,
#             "Stg-Kurztext": "prime GKG ",
#             "HSB-Gesamt": 2.0,
#             "D-Gesamt": 1.0,
#             "M\u00e4nnlich-D": 0.0,
#             "Weiblich-D": 1.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 1.0,
#             "M\u00e4nnlich-A": 0.0,
#             "Weiblich-A": 1.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 2.0,
#             "StdAnf-M": 0.0,
#             "StdAnf-W": 2.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "H"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "HS",
#             "Stg-Nr": 804.0,
#             "Studiengang-Drucktext": "prime WiWi               ",
#             "Abschluss": NaN,
#             "Stg-Kurztext": "prime WiWi",
#             "HSB-Gesamt": 3.0,
#             "D-Gesamt": 0.0,
#             "M\u00e4nnlich-D": 0.0,
#             "Weiblich-D": 0.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 3.0,
#             "M\u00e4nnlich-A": 1.0,
#             "Weiblich-A": 2.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 2.0,
#             "StdAnf-M": 1.0,
#             "StdAnf-W": 1.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "H"
#         },
#         {
#             "St-Ort": "NW",
#             "FAK": "HS",
#             "Stg-Nr": 999.0,
#             "Studiengang-Drucktext": "Vorbereitungsstudium     ",
#             "Abschluss": NaN,
#             "Stg-Kurztext": "VOR       ",
#             "HSB-Gesamt": 15.0,
#             "D-Gesamt": 1.0,
#             "M\u00e4nnlich-D": 1.0,
#             "Weiblich-D": 0.0,
#             "nichtMW-D": 0.0,
#             "A-Gesamt": 14.0,
#             "M\u00e4nnlich-A": 10.0,
#             "Weiblich-A": 4.0,
#             "nichtMW-A": 0.0,
#             "BeurlaubteGesamt": 0.0,
#             "Beurlaubte-M": 0.0,
#             "Beurlaubte-W": 0.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 8.0,
#             "StdAnf-M": 6.0,
#             "StdAnf-W": 2.0,
#             "StdAnf-nichtMW": 0.0,
#             "FAKsort": "H"
#         },
#         {
#             "St-Ort": NaN,
#             "FAK": NaN,
#             "Stg-Nr": NaN,
#             "Studiengang-Drucktext": NaN,
#             "Abschluss": NaN,
#             "Stg-Kurztext": NaN,
#             "HSB-Gesamt": NaN,
#             "D-Gesamt": NaN,
#             "M\u00e4nnlich-D": NaN,
#             "Weiblich-D": NaN,
#             "nichtMW-D": NaN,
#             "A-Gesamt": NaN,
#             "M\u00e4nnlich-A": NaN,
#             "Weiblich-A": NaN,
#             "nichtMW-A": NaN,
#             "BeurlaubteGesamt": NaN,
#             "Beurlaubte-M": NaN,
#             "Beurlaubte-W": NaN,
#             "Beurlaubte-nichtMW": NaN,
#             "StdAnfGesamt": NaN,
#             "StdAnf-M": NaN,
#             "StdAnf-W": NaN,
#             "StdAnf-nichtMW": NaN,
#             "FAKsort": NaN
#         },
#         {
#             "St-Ort": NaN,
#             "FAK": NaN,
#             "Stg-Nr": NaN,
#             "Studiengang-Drucktext": "GESAMT",
#             "Abschluss": NaN,
#             "Stg-Kurztext": NaN,
#             "HSB-Gesamt": 8757.0,
#             "D-Gesamt": 7020.0,
#             "M\u00e4nnlich-D": 3853.0,
#             "Weiblich-D": 3144.0,
#             "nichtMW-D": 23.0,
#             "A-Gesamt": 1737.0,
#             "M\u00e4nnlich-A": 1057.0,
#             "Weiblich-A": 679.0,
#             "nichtMW-A": 1.0,
#             "BeurlaubteGesamt": 121.0,
#             "Beurlaubte-M": 42.0,
#             "Beurlaubte-W": 79.0,
#             "Beurlaubte-nichtMW": 0.0,
#             "StdAnfGesamt": 2120.0,
#             "StdAnf-M": 1153.0,
#             "StdAnf-W": 953.0,
#             "StdAnf-nichtMW": 14.0,
#             "FAKsort": NaN
#         }
#     ]
# }
# Daten erfolgreich in Fakultätsdaten.json gespeichert.
